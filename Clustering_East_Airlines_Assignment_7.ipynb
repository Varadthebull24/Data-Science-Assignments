# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1) Importing Dataset

# %%
data = pd.read_csv("EastWestAirlines.csv")
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# ### 2) Performing Descriptive Analysis

# %%
data.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %% [markdown]
# ### 3) Checking Data Type

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %% [markdown]
# ### 4) Checking for Null and Duplicate Values

# %%
data.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID#, Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award?]
# Index: []

# %% [markdown]
# ### 5) Performing EDA

# %%
for feature in data.columns:
    data=data.copy()
    data[feature].hist(bins=20)
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### 6) Performing Outlier Detection

# %%
data2=data.copy() 
fig, axes=plt.subplots(10,1,figsize=(16,16),sharex=False,sharey=False)
sns.boxplot(x='Balance',data=data2,palette='crest',ax=axes[0])
sns.boxplot(x='Qual_miles',data=data2,palette='crest',ax=axes[1])
sns.boxplot(x='cc1_miles',data=data2,palette='crest',ax=axes[2])
sns.boxplot(x='cc2_miles',data=data2,palette='crest',ax=axes[3])
sns.boxplot(x='cc3_miles',data=data2,palette='crest',ax=axes[4])
sns.boxplot(x='Bonus_miles',data=data2,palette='crest',ax=axes[5])
sns.boxplot(x='Bonus_trans',data=data2,palette='crest',ax=axes[6])
sns.boxplot(x='Flight_miles_12mo',data=data2,palette='crest',ax=axes[7])
sns.boxplot(x='Flight_trans_12',data=data2,palette='crest',ax=axes[8])
sns.boxplot(x='Days_since_enroll',data=data2,palette='crest',ax=axes[9])
plt.tight_layout(pad=2.0)

# %% [markdown]
# ### 7) Hierarchy Clustering

# %%
plt.figure(figsize = (16, 10));
dendrogram = sch.dendrogram(sch.linkage(data, method='average'))

# %%
hc = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'average')

# %%
y_hc = hc.fit_predict(airlines)
Clusters=pd.DataFrame(y_hc,columns=['Clusters'])
Clusters
# Out:
#       Clusters
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 3994         0
# 3995         0
# 3996         0
# 3997         0
# 3998         0
#
# [3999 rows x 1 columns]

# %%
data3 = pd.concat([data,Clusters], axis=1)
data3
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data3.sort_values("Clusters")
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 2658  2678    27438           0          1          1          1         2528
# 2659  2679    14748           0          1          1          1         2210
# 2660  2680    49514           0          1          1          1         4500
# 2661  2681     7457           0          1          1          1        17131
# ...    ...      ...         ...        ...        ...        ...          ...
# 510    516   889456        1024          5          1          1        98959
# 117    120   969559           0          1          1          1         2500
# 1188  1200   837979           0          1          1          1        18372
# 3772  3795   822321           0          5          1          1       138334
# 151    154   930410           0          5          1          1       211284
#
# ...

# %% [markdown]
# ### 8) K-Means

# %%
kmeans = KMeans(n_clusters=14,random_state=0)
kmeans.fit(data)
# Out:
# KMeans(n_clusters=14, random_state=0)

# %%
kmeans.inertia_
# Out:
# 1834070337748.0327

# %%
wcss = []
for i in range(1, 19):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [42967206847420.69,
#  20828852094270.242,
#  11794254039243.766,
#  7554668286111.572,
#  5775051202470.377,
#  4546507928780.688,
#  3702589069199.2085,
#  3276988157640.795,
#  2902566130528.815,
#  2626868222415.188,
#  2388857476451.3633,
#  2145927982985.307,
#  1970924985403.443,
#  1834070337748.0332,
#  1704025192843.4019,
#  1600642706952.2202,
#  1471387695494.5977,
#  1403671270869.3865]

# %%
plt.plot(range(1, 19), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
clusters_new = KMeans(7, random_state=0)
clusters_new.fit(data)
# Out:
# KMeans(n_clusters=7, random_state=0)

# %%
clusters_new.labels_
# Out:
# array([3, 3, 3, ..., 6, 6, 3])

# %%
data4 = pd.DataFrame(clusters_new.labels_, columns =['Cluster ID'])

# %%
data5 = pd.concat([data,data4], axis=1)
data5
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data6=data5.drop(['ID#'], axis=1)

# %%
data6.groupby('Cluster ID').agg(['mean'])
# Out:
#                  Balance   Qual_miles cc1_miles cc2_miles cc3_miles  \
#                     mean         mean      mean      mean      mean
# Cluster ID
# 0           1.275126e+05   230.817708  3.006944  1.013889  1.041667
# 1           7.283600e+05   258.636364  3.500000  1.000000  1.136364
# 2           3.948273e+05   465.400000  3.188235  1.035294  1.000000
# 3           1.980550e+04    96.539196  1.372362  1.017588  1.000000
# 4           2.210648e+05   303.074510  2.917647  1.000000  1.000000
# 5           1.288916e+06  1528.000000  3.000000  1.000000  1.000000
# 6           6.479469e+04   113.580675  2.500938  1.011257  1.020638
#
#              Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#                     mean        mean              mean            mean
# Cluster ID
# 0           32397.265625   16.447917        783.171875        2.295139
# 1           62470.818182   22.000000       1600.909091        5.727273
# ...

# %%
data6['Cluster ID'].value_counts()
# Out:
# 3    1990
# 6    1066
# 0     576
# 4     255
# 2      85
# 1      22
# 5       5
# Name: Cluster ID, dtype: int64

# %% [markdown]
# ### 9) DBSCAN

# %%
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
values=airlines.values
values
# Out:
# array([[    1, 28143,     0, ...,     0,  7000,     0],
#        [    2, 19244,     0, ...,     0,  6968,     0],
#        [    3, 41354,     0, ...,     0,  7034,     0],
#        ...,
#        [ 4019, 73597,     0, ...,     0,  1402,     1],
#        [ 4020, 54899,     0, ...,     1,  1401,     0],
#        [ 4021,  3016,     0, ...,     0,  1398,     0]], dtype=int64)

# %%
stdscaler = StandardScaler().fit(values)
x1 = stscaler.transform(values)

# %%
dbscan = DBSCAN(eps=0.82, min_samples=6)
dbscan.fit(x1)
# Out:
# DBSCAN(eps=0.82, min_samples=6)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
col=pd.DataFrame(dbscan.labels_,columns=['Cluster'])

# %%
data7 = pd.concat([data,col],axis=1)
data7
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data7['Cluster'].value_counts()
# Out:
#  0    2182
#  1     903
# -1     879
#  3      16
#  4       7
#  5       7
#  2       5
# Name: Cluster, dtype: int64
